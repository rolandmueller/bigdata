# %%
# import symbolic capability to Python
from sympy import *
# print things all pretty
from sympy.abc import *
from sympy.plotting import plot
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display
init_printing()

# %% [markdown]
# Variables:
# * $n$: number of rows of the data
# * $m$: number of binary columns (attributes) of the data
# * $d$: depth of the decision tree

# %% [markdown]
# # Exercise
#
# You have a dataset with $m$ binary columns and $n$ rows. A given decision tree has the depth $d$.git/
#
# Questions:
# 1. How many different decision trees with depth $d=1$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 2. How many different decision trees with depth $d=2$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 3. How many different decision trees with depth $d=3$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 4. How many different decision trees with depth $d=4$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 5. In general, how many different decision trees with depth $d$ are possible for a dataset with $m$ binary columns and $n$ rows?
# 6. In general, how many different decision trees of any depth are possible for a dataset with $m$ binary columns and $n$ rows?
# 7. How many decision trees are possible for $m=4$ binary columns?
# 8. There are $10^{80}$ atoms in the universe. What is the value for $m$ so that the number of decision trees is greater than the number of atoms in the universe?
# 9. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m$ binary columns and $n$ rows?
# 10. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m=3$ binary columns and $n=100$ rows?
# 11. Is the time complexity of the naive testing of all possible decision trees of the same order of growth (same Big O) than $O(2^n)$?

# %% [markdown]
# 1. The number of Decision Trees with depth 1 would be $m$, because each of the $m$ attributes could be the root node.
# * On the second level, for both branches (True and False) all remaining $(m-1)$ attribute could be used. Therefore all combinations of two attributes out of the set of $(m-1)$ attributes are possible. There are $(m-1)^2$ combiantions. The number of Decision Trees with depth 2 would be therefore $m(m-1)^2$.
# * On the third level, for all 4 branches all remaining $(m-2)$ attributed could be used. Therefore all combinations of four attributes out of the set of $(m-2)$ attributes are possible. There are $(m-2)^4$ combiantions. The number of Decision Trees with depth 3 would be therefore $m(m-1)^2(m-2)^4$.
# * On the forth level, for all 8 branches all remaining $(m-3)$ attributed could be used. Therefore all combinations of 8 attributes out of the set of $(m-3)$ attributes are possible. There are $(m-3)^8$ combiantions. The number of Decision Trees with depth 4 would be therefore $m(m-1)^2(m-2)^4(m-3)^8$ or
# $$m^{2^0}(m-1)^{2^1}(m-2)^{2^2}(m-3)^{2^3}$$
# * In general,  for a data set with $m$ attributes, how many decision trees with depth $d$ are possible?
# $$\prod_{i=1}^{d} (m-i-1)^{2^{i-1}} = \prod_{i=0}^{d-1} (m-i)^{2^{i}} $$

# %%
m = symbols("m", positive=True, integer=True)
d = symbols("d", positive=True, integer=True)

# %%
ntrees = Product((m-i)**(2)**i, (i, 0, d-1))
ntrees
# Out:
#  d - 1
# ┬──────┬
# │      │         ⎛ i⎞
# │      │         ⎝2 ⎠
# │      │ (-i + m)
# │      │
#  i = 0

# %%
ntrees.subs({m:4, d: 4})
# Out:
#    3
# ┬──────┬
# │      │         ⎛ i⎞
# │      │         ⎝2 ⎠
# │      │ (-i + 4)
# │      │
#  i = 0

# %% [markdown]
# ### 6. In general, how many different decision trees of any depth are possible for a dataset with $m$ binary columns and $n$ rows?
#
# $$\sum_{d=1}^{m}\prod_{i=0}^{d-1} (m-i)^{2^{i}} $$

# %%
alltrees = summation(ntrees, (d, 1, m))
alltrees
# Out:
#   m
# ______
# ╲
#  ╲      d - 1
#   ╲    ┬──────┬
#    ╲   │      │         ⎛ i⎞
#     ╲  │      │         ⎝2 ⎠
#     ╱  │      │ (-i + m)
#    ╱   │      │
#   ╱     i = 0
#  ╱
# ╱
# ‾‾‾‾‾‾
# d = 1

# %% [markdown]
# ### 7. How many decision trees are possible for $m=4$ binary columns?

# %%
alltrees.evalf(subs={m:4})
# Out:
# 1192.00000000000

# %% [markdown]
# ### 8. There are $10^{80}$ atoms in the universe. What is the value for $m$ so that the number of decision trees is greater than the number of atoms in the universe?

# %% [markdown]
# Number of atoms in the universe: $10^{80}$

# %%
alltrees.evalf(subs={m:9})
# Out:
# 1.52789736224490e+112

# %% [markdown]
# ### 9. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m$ binary columns and $n$ rows?

# %%
operations = summation(Product((m-i)**(2)**i * d * n, (i, 0, d-1)), (d, 1, m))
operations
# Out:
#   m
# ______
# ╲
#  ╲      d - 1
#   ╲    ┬──────┬
#    ╲   │      │             ⎛ i⎞
#     ╲  │      │             ⎝2 ⎠
#     ╱  │      │ d⋅n⋅(-i + m)
#    ╱   │      │
#   ╱     i = 0
#  ╱
# ╱
# ‾‾‾‾‾‾
# d = 1

# %% [markdown]
# ### 10. How many operations (steps) does the naive testing take of all possible decision trees for a dataset with $m=3$ binary columns and $n=100$ rows?

# %%
operations.evalf(subs={m:3, n:100})
# Out:
# 324480300.000000

# %% [markdown]
# ### 11. Is the time complexity of the naive testing of all possible decision trees of the same order of growth (same Big O) than $O(2^n)$?

# %%
f_quadratic = n**2

# %%
limit(operations / f_quadratic, n, oo)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sympy/series/limits.py in doit(self, **hints)
#     212         try:
# --> 213             r = gruntz(e, z, z0, dir)
#     214             if r is S.NaN:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sympy/series/gruntz.py in gruntz(e, z, z0, dir)
#     647     if z0 == oo:
# --> 648         r = limitinf(e, z)
#     649     elif z0 == -oo:
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sympy/core/cache.py in wrapper(*args, **kwargs)
#      92                 try:
# ---> 93                     retval = cfunc(*args, **kwargs)
#      94                 except TypeError:
#
# ...
